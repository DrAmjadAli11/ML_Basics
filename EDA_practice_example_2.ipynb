# %%
# EDA
# Expolatroy Data Analysis

# %%
# Importing the Installed libraries

import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation

# %%
# Load the Dataset

df=sns.load_dataset('iris')

# %%
# To display the top 5 rows

df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# To display the botton 5 rows

df.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# check the Datatype of the Data set because sometime data 
# is stored as a string

df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# check the column name

df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# Renaming the column

df = df.rename(columns={"sepal_length": "SL", "sepal_width": "SW",
                        "petal_length": "PL", "petal_width": "PW" })
df.head(5)
# Out:
#     SL   SW   PL   PW species
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa
# 2  4.7  3.2  1.3  0.2  setosa
# 3  4.6  3.1  1.5  0.2  setosa
# 4  5.0  3.6  1.4  0.2  setosa

# %%
# check the shape of the Data
df.shape
# Out:
# (150, 5)

# %%
# check the statiscal values of the data
df.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333
# std      0.828066    0.435866    1.765298    0.762238
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.count()      # Used to count the number of rows
# Out:
# SL         150
# SW         150
# PL         150
# PW         150
# species    150
# dtype: int64

# %%
# check the missing values

print(df.isnull().sum())
# Out:
# SL         0
# SW         0
# PL         0
# PW         0
# species    0
# dtype: int64

# %%
# Detect the outliers

sns.boxplot(x=df['SL'])
# Out:
# <Axes: xlabel='SL'>

# %%
sns.boxplot(x=df['SW'])
# Out:
# <Axes: xlabel='SW'>

# %%
sns.boxplot(x=df['PL'])
# Out:
# <Axes: xlabel='PL'>

# %%
sns.boxplot(x=df['PW'])
# Out:
# <Axes: xlabel='PW'>

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# SL    1.3
# SW    0.5
# PL    3.5
# PW    1.5
# dtype: float64
# C:\Users\AMJAD ALI\AppData\Local\Temp\ipykernel_61904\4249959737.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = df.quantile(0.25)
# C:\Users\AMJAD ALI\AppData\Local\Temp\ipykernel_61904\4249959737.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = df.quantile(0.75)

# %%
# correlation of different features

df.corr()
# Out:
# C:\Users\AMJAD ALI\AppData\Local\Temp\ipykernel_61904\2843775414.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           SL        SW        PL        PW
# SL  1.000000 -0.117570  0.871754  0.817941
# SW -0.117570  1.000000 -0.428440 -0.366126
# PL  0.871754 -0.428440  1.000000  0.962865
# PW  0.817941 -0.366126  0.962865  1.000000

# %%
# Adjusting the Size of Figure
plt.figure(figsize=(10,5))

# calculating the Correlation
correlation = df.corr()

# Displaying the correlation using the Heap Map
sns.heatmap(correlation,cmap="BrBG",annot=True) 
# Br: Brown. B: Blue, G: Green

#correlation
# Out:
# C:\Users\AMJAD ALI\AppData\Local\Temp\ipykernel_61904\55898597.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# <Axes: >

# %%
#Relation Plot
sns.pairplot(df)

# %%
#ScatterPLot relation between two continous variable

sns.relplot(x='SL',y='SW',data=df)

# %%
#distribution of data
#! distplot

sns.distplot(df['SL'])
# Out:
# C:\Users\AMJAD ALI\AppData\Local\Temp\ipykernel_61904\1415464636.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SL'])
# <Axes: xlabel='SL', ylabel='Density'>
